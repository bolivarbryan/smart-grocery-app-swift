# %% [markdown]
# ## Import dependencies

# %%
from keras.models import load_model
import coremltools
# Out:
# Using TensorFlow backend.

# %% [markdown]
# ## Load Keras model

# %%
model = load_model('../food101-model.hdf5')

# %% [markdown]
# ## Convert Keras model to Core ML model

# %%
coreml_model = coremltools.converters.keras.convert(model, 
                                                    input_names=['image'],
                                                    image_input_names='image',
                                                    image_scale=2/255.0,
                                                    red_bias=-1,
                                                    green_bias=-1,
                                                    blue_bias=-1,
                                                    output_names=['confidence'], 
                                                    class_labels='labels.txt')
# Out:
# 0 : input_1, <keras.engine.topology.InputLayer object at 0x7f44775bcb10>
# 1 : convolution2d_1, <keras.layers.convolutional.Convolution2D object at 0x7f447765a350>
# 2 : convolution2d_1__activation__, <keras.layers.core.Activation object at 0x7f44a058fcd0>
# 3 : batchnormalization_1, <keras.layers.normalization.BatchNormalization object at 0x7f44775bcd10>
# 4 : convolution2d_2, <keras.layers.convolutional.Convolution2D object at 0x7f447758ec50>
# 5 : convolution2d_2__activation__, <keras.layers.core.Activation object at 0x7f4435d39450>
# 6 : batchnormalization_2, <keras.layers.normalization.BatchNormalization object at 0x7f447755a390>
# 7 : convolution2d_3, <keras.layers.convolutional.Convolution2D object at 0x7f44774b6b90>
# 8 : convolution2d_3__activation__, <keras.layers.core.Activation object at 0x7f4435d39b10>
# 9 : batchnormalization_3, <keras.layers.normalization.BatchNormalization object at 0x7f44774ee650>
# 10 : maxpooling2d_1, <keras.layers.pooling.MaxPooling2D object at 0x7f447745bd90>
# 11 : convolution2d_4, <keras.layers.convolutional.Convolution2D object at 0x7f44771ca990>
# 12 : convolution2d_4__activation__, <keras.layers.core.Activation object at 0x7f4435d39990>
# 13 : batchnormalization_4, <keras.layers.normalization.BatchNormalization object at 0x7f447718dcd0>
# 14 : convolution2d_5, <keras.layers.convolutional.Convolution2D object at 0x7f44771b6a50>
# 15 : convolution2d_5__activation__, <keras.layers.core.Activation object at 0x7f4435d393d0>
# 16 : batchnormalization_5, <keras.layers.normalization.BatchNormalization object at 0x7f4477107f90>
# 17 : maxpooling2d_2, <keras.layers.pooling.MaxPooling2D object at 0x7f44770da890>
# 18 : convolution2d_9, <keras.layers.convolutional.Convolution2D object at 0x7f44770fee50>
# 19 : convolution2d_9__activation__, <keras.layers.core.Activation object at 0x7f4435d39490>
# 20 : batchnormalization_9, <keras.layers.normalization.BatchNormalization object at 0x7f4477041590>
# 21 : convolution2d_7, <keras.layers.convolutional.Convolution2D object at 0x7f447707fe90>
# 22 : convolution2d_7__activation__, <keras.layers.core.Activation object at 0x7f4435d39310>
# 23 : convolution2d_10, <keras.layers.convolutional.Convolution2D object at 0x7f4477022ad0>
# 24 : convolution2d_10__activation__, <keras.layers.core.Activation object at 0x7f4435d399d0>
# 25 : batchnormalization_7, <keras.layers.normalization.BatchNormalization object at 0x7f4476f93c10>
# 26 : batchnormalization_10, <keras.layers.normalization.BatchNormalization object at 0x7f4476fb7bd0>
# 27 : averagepooling2d_1, <keras.layers.pooling.AveragePooling2D object at 0x7f4476f03f90>
# 28 : convolution2d_6, <keras.layers.convolutional.Convolution2D object at 0x7f4476edaa90>
# 29 : convolution2d_6__activation__, <keras.layers.core.Activation object at 0x7f4435d39bd0>
# 30 : convolution2d_8, <keras.layers.convolutional.Convolution2D object at 0x7f4476e9dd10>
# 31 : convolution2d_8__activation__, <keras.layers.core.Activation object at 0x7f4435d39c10>
# 32 : convolution2d_11, <keras.layers.convolutional.Convolution2D object at 0x7f4476e4ce10>
# 33 : convolution2d_11__activation__, <keras.layers.core.Activation object at 0x7f4435d39a10>
# 34 : convolution2d_12, <keras.layers.convolutional.Convolution2D object at 0x7f4476e6dcd0>
# 35 : convolution2d_12__activation__, <keras.layers.core.Activation object at 0x7f4435d39350>
# 36 : batchnormalization_6, <keras.layers.normalization.BatchNormalization object at 0x7f4476e14b50>
# 37 : batchnormalization_8, <keras.layers.normalization.BatchNormalization object at 0x7f4476e37990>
# 38 : batchnormalization_11, <keras.layers.normalization.BatchNormalization object at 0x7f4476d88f50>
# 39 : batchnormalization_12, <keras.layers.normalization.BatchNormalization object at 0x7f4476d5d490>
# 40 : mixed0, <keras.engine.topology.Merge object at 0x7f4476cf6f10>
# 41 : convolution2d_16, <keras.layers.convolutional.Convolution2D object at 0x7f4476c4ea90>
# 42 : convolution2d_16__activation__, <keras.layers.core.Activation object at 0x7f4435d39b50>
# 43 : batchnormalization_16, <keras.layers.normalization.BatchNormalization object at 0x7f4476c13990>
# 44 : convolution2d_14, <keras.layers.convolutional.Convolution2D object at 0x7f4476c3ff50>
# 45 : convolution2d_14__activation__, <keras.layers.core.Activation object at 0x7f4435d39a50>
# 46 : convolution2d_17, <keras.layers.convolutional.Convolution2D object at 0x7f4476bf5990>
# 47 : convolution2d_17__activation__, <keras.layers.core.Activation object at 0x7f4435d39a90>
# 48 : batchnormalization_14, <keras.layers.normalization.BatchNormalization object at 0x7f4476b63d10>
# 49 : batchnormalization_17, <keras.layers.normalization.BatchNormalization object at 0x7f4476b09c90>
# 50 : averagepooling2d_2, <keras.layers.pooling.AveragePooling2D object at 0x7f4476b2d850>
# 51 : convolution2d_13, <keras.layers.convolutional.Convolution2D object at 0x7f4476ab1650>
# 52 : convolution2d_13__activation__, <keras.layers.core.Activation object at 0x7f4435d39b90>
# 53 : convolution2d_15, <keras.layers.convolutional.Convolution2D object at 0x7f4476a62f10>
# 54 : convolution2d_15__activation__, <keras.layers.core.Activation object at 0x7f4435d39ad0>
# 55 : convolution2d_18, <keras.layers.convolutional.Convolution2D object at 0x7f4476a20c50>
# 56 : convolution2d_18__activation__, <keras.layers.core.Activation object at 0x7f447766afd0>
# 57 : convolution2d_19, <keras.layers.convolutional.Convolution2D object at 0x7f44769c4a50>
# 58 : convolution2d_19__activation__, <keras.layers.core.Activation object at 0x7f447766ad90>
# 59 : batchnormalization_13, <keras.layers.normalization.BatchNormalization object at 0x7f44769d6f90>
# 60 : batchnormalization_15, <keras.layers.normalization.BatchNormalization object at 0x7f44769fde90>
# 61 : batchnormalization_18, <keras.layers.normalization.BatchNormalization object at 0x7f447694c5d0>
# 62 : batchnormalization_19, <keras.layers.normalization.BatchNormalization object at 0x7f4476928bd0>
# 63 : mixed1, <keras.engine.topology.Merge object at 0x7f44768a8550>
# 64 : convolution2d_23, <keras.layers.convolutional.Convolution2D object at 0x7f4476817c90>
# 65 : convolution2d_23__activation__, <keras.layers.core.Activation object at 0x7f447766acd0>
# 66 : batchnormalization_23, <keras.layers.normalization.BatchNormalization object at 0x7f44767d8f50>
# 67 : convolution2d_21, <keras.layers.convolutional.Convolution2D object at 0x7f447678ac10>
# 68 : convolution2d_21__activation__, <keras.layers.core.Activation object at 0x7f447766aa90>
# 69 : convolution2d_24, <keras.layers.convolutional.Convolution2D object at 0x7f44767587d0>
# 70 : convolution2d_24__activation__, <keras.layers.core.Activation object at 0x7f447766a350>
# 71 : batchnormalization_21, <keras.layers.normalization.BatchNormalization object at 0x7f447672f8d0>
# 72 : batchnormalization_24, <keras.layers.normalization.BatchNormalization object at 0x7f44766d5490>
# 73 : averagepooling2d_3, <keras.layers.pooling.AveragePooling2D object at 0x7f44766f9a50>
# 74 : convolution2d_20, <keras.layers.convolutional.Convolution2D object at 0x7f447667a850>
# 75 : convolution2d_20__activation__, <keras.layers.core.Activation object at 0x7f447766add0>
# 76 : convolution2d_22, <keras.layers.convolutional.Convolution2D object at 0x7f44765c0510>
# 77 : convolution2d_22__activation__, <keras.layers.core.Activation object at 0x7f447766a2d0>
# 78 : convolution2d_25, <keras.layers.convolutional.Convolution2D object at 0x7f44765eae50>
# 79 : convolution2d_25__activation__, <keras.layers.core.Activation object at 0x7f447766ae50>
# 80 : convolution2d_26, <keras.layers.convolutional.Convolution2D object at 0x7f447658ec50>
# 81 : convolution2d_26__activation__, <keras.layers.core.Activation object at 0x7f447766a110>
# 82 : batchnormalization_20, <keras.layers.normalization.BatchNormalization object at 0x7f44765b5a50>
# 83 : batchnormalization_22, <keras.layers.normalization.BatchNormalization object at 0x7f4476544b90>
# 84 : batchnormalization_25, <keras.layers.normalization.BatchNormalization object at 0x7f447657f590>
# 85 : batchnormalization_26, <keras.layers.normalization.BatchNormalization object at 0x7f44764ef990>
# 86 : mixed2, <keras.engine.topology.Merge object at 0x7f447646f650>
# 87 : convolution2d_28, <keras.layers.convolutional.Convolution2D object at 0x7f447638dfd0>
# 88 : convolution2d_28__activation__, <keras.layers.core.Activation object at 0x7f447766a5d0>
# 89 : batchnormalization_28, <keras.layers.normalization.BatchNormalization object at 0x7f44763a2cd0>
# 90 : convolution2d_29, <keras.layers.convolutional.Convolution2D object at 0x7f4476360c50>
# 91 : convolution2d_29__activation__, <keras.layers.core.Activation object at 0x7f447766a550>
# 92 : batchnormalization_29, <keras.layers.normalization.BatchNormalization object at 0x7f447631d9d0>
# 93 : convolution2d_27, <keras.layers.convolutional.Convolution2D object at 0x7f44762f8890>
# 94 : convolution2d_27__activation__, <keras.layers.core.Activation object at 0x7f447766a610>
# 95 : convolution2d_30, <keras.layers.convolutional.Convolution2D object at 0x7f447629ddd0>
# 96 : convolution2d_30__activation__, <keras.layers.core.Activation object at 0x7f447766a650>
# 97 : batchnormalization_27, <keras.layers.normalization.BatchNormalization object at 0x7f4476210e50>
# 98 : batchnormalization_30, <keras.layers.normalization.BatchNormalization object at 0x7f4476231dd0>
# 99 : maxpooling2d_3, <keras.layers.pooling.MaxPooling2D object at 0x7f4476182fd0>
# 100 : mixed3, <keras.engine.topology.Merge object at 0x7f4476170cd0>
# 101 : convolution2d_35, <keras.layers.convolutional.Convolution2D object at 0x7f447611ba10>
# 102 : convolution2d_35__activation__, <keras.layers.core.Activation object at 0x7f447766ab90>
# 103 : batchnormalization_35, <keras.layers.normalization.BatchNormalization object at 0x7f4476131e50>
# 104 : convolution2d_36, <keras.layers.convolutional.Convolution2D object at 0x7f44760dab50>
# 105 : convolution2d_36__activation__, <keras.layers.core.Activation object at 0x7f447766a090>
# 106 : batchnormalization_36, <keras.layers.normalization.BatchNormalization object at 0x7f44760988d0>
# 107 : convolution2d_32, <keras.layers.convolutional.Convolution2D object at 0x7f447606e790>
# 108 : convolution2d_32__activation__, <keras.layers.core.Activation object at 0x7f447766a950>
# 109 : convolution2d_37, <keras.layers.convolutional.Convolution2D object at 0x7f4476025f10>
# 110 : convolution2d_37__activation__, <keras.layers.core.Activation object at 0x7f447766ac10>
# 111 : batchnormalization_32, <keras.layers.normalization.BatchNormalization object at 0x7f4475f87d90>
# 112 : batchnormalization_37, <keras.layers.normalization.BatchNormalization object at 0x7f4475fa7cd0>
# 113 : convolution2d_33, <keras.layers.convolutional.Convolution2D object at 0x7f4475f78fd0>
# 114 : convolution2d_33__activation__, <keras.layers.core.Activation object at 0x7f447766a890>
# 115 : convolution2d_38, <keras.layers.convolutional.Convolution2D object at 0x7f4475ee6bd0>
# 116 : convolution2d_38__activation__, <keras.layers.core.Activation object at 0x7f447766a390>
# 117 : batchnormalization_33, <keras.layers.normalization.BatchNormalization object at 0x7f4475e43a50>
# 118 : batchnormalization_38, <keras.layers.normalization.BatchNormalization object at 0x7f4475e65890>
# 119 : averagepooling2d_4, <keras.layers.pooling.AveragePooling2D object at 0x7f4475e37f90>
# 120 : convolution2d_31, <keras.layers.convolutional.Convolution2D object at 0x7f4475da6890>
# 121 : convolution2d_31__activation__, <keras.layers.core.Activation object at 0x7f447766a710>
# 122 : convolution2d_34, <keras.layers.convolutional.Convolution2D object at 0x7f4475d53910>
# 123 : convolution2d_34__activation__, <keras.layers.core.Activation object at 0x7f447766aa50>
# 124 : convolution2d_39, <keras.layers.convolutional.Convolution2D object at 0x7f4475d7e990>
# 125 : convolution2d_39__activation__, <keras.layers.core.Activation object at 0x7f447766a410>
# 126 : convolution2d_40, <keras.layers.convolutional.Convolution2D object at 0x7f4475d23790>
# 127 : convolution2d_40__activation__, <keras.layers.core.Activation object at 0x7f447766af50>
# 128 : batchnormalization_31, <keras.layers.normalization.BatchNormalization object at 0x7f4475cc9e50>
# 129 : batchnormalization_34, <keras.layers.normalization.BatchNormalization object at 0x7f4475ceddd0>
# 130 : batchnormalization_39, <keras.layers.normalization.BatchNormalization object at 0x7f4475c92990>
# 131 : batchnormalization_40, <keras.layers.normalization.BatchNormalization object at 0x7f4475c2bed0>
# 132 : mixed4, <keras.engine.topology.Merge object at 0x7f4475b83a50>
# 133 : convolution2d_45, <keras.layers.convolutional.Convolution2D object at 0x7f4475b1efd0>
# 134 : convolution2d_45__activation__, <keras.layers.core.Activation object at 0x7f447766ab50>
# 135 : batchnormalization_45, <keras.layers.normalization.BatchNormalization object at 0x7f4475acd1d0>
# 136 : convolution2d_46, <keras.layers.convolutional.Convolution2D object at 0x7f4475af5650>
# 137 : convolution2d_46__activation__, <keras.layers.core.Activation object at 0x7f447766a8d0>
# 138 : batchnormalization_46, <keras.layers.normalization.BatchNormalization object at 0x7f4475ab1dd0>
# 139 : convolution2d_42, <keras.layers.convolutional.Convolution2D object at 0x7f4475a0bf50>
# 140 : convolution2d_42__activation__, <keras.layers.core.Activation object at 0x7f447766a450>
# 141 : convolution2d_47, <keras.layers.convolutional.Convolution2D object at 0x7f44759c2810>
# 142 : convolution2d_47__activation__, <keras.layers.core.Activation object at 0x7f447766a990>
# 143 : batchnormalization_42, <keras.layers.normalization.BatchNormalization object at 0x7f44759b1b90>
# 144 : batchnormalization_47, <keras.layers.normalization.BatchNormalization object at 0x7f4475958b10>
# 145 : convolution2d_43, <keras.layers.convolutional.Convolution2D object at 0x7f447597b6d0>
# 146 : convolution2d_43__activation__, <keras.layers.core.Activation object at 0x7f447766a590>
# 147 : convolution2d_48, <keras.layers.convolutional.Convolution2D object at 0x7f44758814d0>
# 148 : convolution2d_48__activation__, <keras.layers.core.Activation object at 0x7f447766a290>
# 149 : batchnormalization_43, <keras.layers.normalization.BatchNormalization object at 0x7f447585af90>
# 150 : batchnormalization_48, <keras.layers.normalization.BatchNormalization object at 0x7f4475801e90>
# 151 : averagepooling2d_5, <keras.layers.pooling.AveragePooling2D object at 0x7f44757ce5d0>
# 152 : convolution2d_41, <keras.layers.convolutional.Convolution2D object at 0x7f44757bcd90>
# 153 : convolution2d_41__activation__, <keras.layers.core.Activation object at 0x7f447766ae10>
# 154 : convolution2d_44, <keras.layers.convolutional.Convolution2D object at 0x7f4475766e10>
# 155 : convolution2d_44__activation__, <keras.layers.core.Activation object at 0x7f447766a4d0>
# 156 : convolution2d_49, <keras.layers.convolutional.Convolution2D object at 0x7f4475717e50>
# 157 : convolution2d_49__activation__, <keras.layers.core.Activation object at 0x7f447766a210>
# 158 : convolution2d_50, <keras.layers.convolutional.Convolution2D object at 0x7f447573ac90>
# 159 : convolution2d_50__activation__, <keras.layers.core.Activation object at 0x7f447766ad10>
# 160 : batchnormalization_41, <keras.layers.normalization.BatchNormalization object at 0x7f44756dfa90>
# 161 : batchnormalization_44, <keras.layers.normalization.BatchNormalization object at 0x7f44756878d0>
# 162 : batchnormalization_49, <keras.layers.normalization.BatchNormalization object at 0x7f4475656fd0>
# 163 : batchnormalization_50, <keras.layers.normalization.BatchNormalization object at 0x7f447562a710>
# 164 : mixed5, <keras.engine.topology.Merge object at 0x7f4475546fd0>
# 165 : convolution2d_55, <keras.layers.convolutional.Convolution2D object at 0x7f447551f7d0>
# 166 : convolution2d_55__activation__, <keras.layers.core.Activation object at 0x7f447766a510>
# 167 : batchnormalization_55, <keras.layers.normalization.BatchNormalization object at 0x7f44754e46d0>
# 168 : convolution2d_56, <keras.layers.convolutional.Convolution2D object at 0x7f447548eb50>
# 169 : convolution2d_56__activation__, <keras.layers.core.Activation object at 0x7f447766a9d0>
# 170 : batchnormalization_56, <keras.layers.normalization.BatchNormalization object at 0x7f4475448150>
# 171 : convolution2d_52, <keras.layers.convolutional.Convolution2D object at 0x7f4475436bd0>
# 172 : convolution2d_52__activation__, <keras.layers.core.Activation object at 0x7f447766a850>
# 173 : convolution2d_57, <keras.layers.convolutional.Convolution2D object at 0x7f44753f59d0>
# 174 : convolution2d_57__activation__, <keras.layers.core.Activation object at 0x7f447766aad0>
# 175 : batchnormalization_52, <keras.layers.normalization.BatchNormalization object at 0x7f447534c7d0>
# 176 : batchnormalization_57, <keras.layers.normalization.BatchNormalization object at 0x7f4475371610>
# 177 : convolution2d_53, <keras.layers.convolutional.Convolution2D object at 0x7f4475316bd0>
# 178 : convolution2d_53__activation__, <keras.layers.core.Activation object at 0x7f447766a750>
# 179 : convolution2d_58, <keras.layers.convolutional.Convolution2D object at 0x7f447529a450>
# 180 : convolution2d_58__activation__, <keras.layers.core.Activation object at 0x7f447766ac50>
# 181 : batchnormalization_53, <keras.layers.normalization.BatchNormalization object at 0x7f4475206d50>
# 182 : batchnormalization_58, <keras.layers.normalization.BatchNormalization object at 0x7f447522ccd0>
# 183 : averagepooling2d_6, <keras.layers.pooling.AveragePooling2D object at 0x7f44751d1890>
# 184 : convolution2d_51, <keras.layers.convolutional.Convolution2D object at 0x7f4475154110>
# 185 : convolution2d_51__activation__, <keras.layers.core.Activation object at 0x7f447766a150>
# 186 : convolution2d_54, <keras.layers.convolutional.Convolution2D object at 0x7f4475103fd0>
# 187 : convolution2d_54__activation__, <keras.layers.core.Activation object at 0x7f447766a250>
# 188 : convolution2d_59, <keras.layers.convolutional.Convolution2D object at 0x7f44750c3c90>
# 189 : convolution2d_59__activation__, <keras.layers.core.Activation object at 0x7f447766a3d0>
# 190 : convolution2d_60, <keras.layers.convolutional.Convolution2D object at 0x7f44750dfa90>
# 191 : convolution2d_60__activation__, <keras.layers.core.Activation object at 0x7f447766a790>
# 192 : batchnormalization_51, <keras.layers.normalization.BatchNormalization object at 0x7f44750fafd0>
# 193 : batchnormalization_54, <keras.layers.normalization.BatchNormalization object at 0x7f44750a0ed0>
# 194 : batchnormalization_59, <keras.layers.normalization.BatchNormalization object at 0x7f4475058950>
# 195 : batchnormalization_60, <keras.layers.normalization.BatchNormalization object at 0x7f4474fc9c10>
# 196 : mixed6, <keras.engine.topology.Merge object at 0x7f4474f49a10>
# 197 : convolution2d_65, <keras.layers.convolutional.Convolution2D object at 0x7f4474f39cd0>
# 198 : convolution2d_65__activation__, <keras.layers.core.Activation object at 0x7f447766a190>
# 199 : batchnormalization_65, <keras.layers.normalization.BatchNormalization object at 0x7f4474ee4810>
# 200 : convolution2d_66, <keras.layers.convolutional.Convolution2D object at 0x7f4474eaac50>
# 201 : convolution2d_66__activation__, <keras.layers.core.Activation object at 0x7f447766aa10>
# 202 : batchnormalization_66, <keras.layers.normalization.BatchNormalization object at 0x7f4474e7c890>
# 203 : convolution2d_62, <keras.layers.convolutional.Convolution2D object at 0x7f4474dd2f50>
# 204 : convolution2d_62__activation__, <keras.layers.core.Activation object at 0x7f447766a7d0>
# 205 : convolution2d_67, <keras.layers.convolutional.Convolution2D object at 0x7f4474d8b950>
# 206 : convolution2d_67__activation__, <keras.layers.core.Activation object at 0x7f447766abd0>
# 207 : batchnormalization_62, <keras.layers.normalization.BatchNormalization object at 0x7f4474d68cd0>
# 208 : batchnormalization_67, <keras.layers.normalization.BatchNormalization object at 0x7f4474d0ac10>
# 209 : convolution2d_63, <keras.layers.convolutional.Convolution2D object at 0x7f4474cc2690>
# 210 : convolution2d_63__activation__, <keras.layers.core.Activation object at 0x7f447766ac90>
# 211 : convolution2d_68, <keras.layers.convolutional.Convolution2D object at 0x7f4474c48b90>
# 212 : convolution2d_68__activation__, <keras.layers.core.Activation object at 0x7f447766af10>
# 213 : batchnormalization_63, <keras.layers.normalization.BatchNormalization object at 0x7f4474c23990>
# 214 : batchnormalization_68, <keras.layers.normalization.BatchNormalization object at 0x7f4474bc77d0>
# 215 : averagepooling2d_7, <keras.layers.pooling.AveragePooling2D object at 0x7f4474beed90>
# 216 : convolution2d_61, <keras.layers.convolutional.Convolution2D object at 0x7f4474b09850>
# 217 : convolution2d_61__activation__, <keras.layers.core.Activation object at 0x7f447766a690>
# 218 : convolution2d_64, <keras.layers.convolutional.Convolution2D object at 0x7f4474b33850>
# 219 : convolution2d_64__activation__, <keras.layers.core.Activation object at 0x7f447766af90>
# 220 : convolution2d_69, <keras.layers.convolutional.Convolution2D object at 0x7f4474ae08d0>
# 221 : convolution2d_69__activation__, <keras.layers.core.Activation object at 0x7f447766a910>
# 222 : convolution2d_70, <keras.layers.convolutional.Convolution2D object at 0x7f4474a83950>
# 223 : convolution2d_70__activation__, <keras.layers.core.Activation object at 0x7f447766aed0>
# 224 : batchnormalization_61, <keras.layers.normalization.BatchNormalization object at 0x7f4474aa9d90>
# 225 : batchnormalization_64, <keras.layers.normalization.BatchNormalization object at 0x7f4474a4ed10>
# 226 : batchnormalization_69, <keras.layers.normalization.BatchNormalization object at 0x7f4474a718d0>
# 227 : batchnormalization_70, <keras.layers.normalization.BatchNormalization object at 0x7f44749f66d0>
# 228 : mixed7, <keras.engine.topology.Merge object at 0x7f4474963990>
# 229 : convolution2d_73, <keras.layers.convolutional.Convolution2D object at 0x7f44748e6790>
# 230 : convolution2d_73__activation__, <keras.layers.core.Activation object at 0x7f447766a490>
# 231 : batchnormalization_73, <keras.layers.normalization.BatchNormalization object at 0x7f44748fb450>
# 232 : convolution2d_74, <keras.layers.convolutional.Convolution2D object at 0x7f4474856590>
# 233 : convolution2d_74__activation__, <keras.layers.core.Activation object at 0x7f447766a6d0>
# 234 : batchnormalization_74, <keras.layers.normalization.BatchNormalization object at 0x7f4474811d90>
# 235 : convolution2d_71, <keras.layers.convolutional.Convolution2D object at 0x7f44747ecbd0>
# 236 : convolution2d_71__activation__, <keras.layers.core.Activation object at 0x7f447766a050>
# 237 : convolution2d_75, <keras.layers.convolutional.Convolution2D object at 0x7f447479b1d0>
# 238 : convolution2d_75__activation__, <keras.layers.core.Activation object at 0x7f447766ad50>
# 239 : batchnormalization_71, <keras.layers.normalization.BatchNormalization object at 0x7f4474714ad0>
# 240 : batchnormalization_75, <keras.layers.normalization.BatchNormalization object at 0x7f4474725c10>
# 241 : convolution2d_72, <keras.layers.convolutional.Convolution2D object at 0x7f44746dc610>
# 242 : convolution2d_72__activation__, <keras.layers.core.Activation object at 0x7f4436aba650>
# 243 : convolution2d_76, <keras.layers.convolutional.Convolution2D object at 0x7f447464fe50>
# 244 : convolution2d_76__activation__, <keras.layers.core.Activation object at 0x7f4436ababd0>
# 245 : batchnormalization_72, <keras.layers.normalization.BatchNormalization object at 0x7f447463ee50>
# 246 : batchnormalization_76, <keras.layers.normalization.BatchNormalization object at 0x7f44745e0dd0>
# 247 : averagepooling2d_8, <keras.layers.pooling.AveragePooling2D object at 0x7f4474598850>
# 248 : mixed8, <keras.engine.topology.Merge object at 0x7f4474521d50>
# 249 : convolution2d_81, <keras.layers.convolutional.Convolution2D object at 0x7f4474537650>
# 250 : convolution2d_81__activation__, <keras.layers.core.Activation object at 0x7f4436aba3d0>
# 251 : batchnormalization_81, <keras.layers.normalization.BatchNormalization object at 0x7f44744e2e50>
# 252 : convolution2d_78, <keras.layers.convolutional.Convolution2D object at 0x7f447448db50>
# 253 : convolution2d_78__activation__, <keras.layers.core.Activation object at 0x7f4436aba690>
# 254 : convolution2d_82, <keras.layers.convolutional.Convolution2D object at 0x7f4474448950>
# 255 : convolution2d_82__activation__, <keras.layers.core.Activation object at 0x7f44775bc490>
# 256 : batchnormalization_78, <keras.layers.normalization.BatchNormalization object at 0x7f447441e750>
# 257 : batchnormalization_82, <keras.layers.normalization.BatchNormalization object at 0x7f44743c4590>
# 258 : convolution2d_79, <keras.layers.convolutional.Convolution2D object at 0x7f44743e9b50>
# 259 : convolution2d_79__activation__, <keras.layers.core.Activation object at 0x7f44775bc450>
# 260 : convolution2d_80, <keras.layers.convolutional.Convolution2D object at 0x7f447436c3d0>
# 261 : convolution2d_80__activation__, <keras.layers.core.Activation object at 0x7f44775bc610>
# 262 : convolution2d_83, <keras.layers.convolutional.Convolution2D object at 0x7f44742dbcd0>
# 263 : convolution2d_83__activation__, <keras.layers.core.Activation object at 0x7f44775bc590>
# 264 : convolution2d_84, <keras.layers.convolutional.Convolution2D object at 0x7f4474280ad0>
# 265 : convolution2d_84__activation__, <keras.layers.core.Activation object at 0x7f44775bc390>
# 266 : averagepooling2d_9, <keras.layers.pooling.AveragePooling2D object at 0x7f44742a8fd0>
# 267 : convolution2d_77, <keras.layers.convolutional.Convolution2D object at 0x7f44742b9dd0>
# 268 : convolution2d_77__activation__, <keras.layers.core.Activation object at 0x7f44775bc410>
# 269 : batchnormalization_79, <keras.layers.normalization.BatchNormalization object at 0x7f447425d310>
# 270 : batchnormalization_80, <keras.layers.normalization.BatchNormalization object at 0x7f447425d810>
# 271 : batchnormalization_83, <keras.layers.normalization.BatchNormalization object at 0x7f4474217a10>
# 272 : batchnormalization_84, <keras.layers.normalization.BatchNormalization object at 0x7f4474186cd0>
# 273 : convolution2d_85, <keras.layers.convolutional.Convolution2D object at 0x7f4474108550>
# 274 : convolution2d_85__activation__, <keras.layers.core.Activation object at 0x7f44775bc050>
# 275 : batchnormalization_77, <keras.layers.normalization.BatchNormalization object at 0x7f447408a8d0>
# 276 : mixed9_0, <keras.engine.topology.Merge object at 0x7f4474069f50>
# 277 : merge_1, <keras.engine.topology.Merge object at 0x7f447401f990>
# 278 : batchnormalization_85, <keras.layers.normalization.BatchNormalization object at 0x7f44740355d0>
# 279 : mixed9, <keras.engine.topology.Merge object at 0x7f4473fe3f90>
# 280 : convolution2d_90, <keras.layers.convolutional.Convolution2D object at 0x7f4473f9f890>
# 281 : convolution2d_90__activation__, <keras.layers.core.Activation object at 0x7f44775bc3d0>
# 282 : batchnormalization_90, <keras.layers.normalization.BatchNormalization object at 0x7f4473fb6fd0>
# 283 : convolution2d_87, <keras.layers.convolutional.Convolution2D object at 0x7f4473f11710>
# 284 : convolution2d_87__activation__, <keras.layers.core.Activation object at 0x7f44775bc350>
# 285 : convolution2d_91, <keras.layers.convolutional.Convolution2D object at 0x7f4473ec8990>
# 286 : convolution2d_91__activation__, <keras.layers.core.Activation object at 0x7f44775bc290>
# 287 : batchnormalization_87, <keras.layers.normalization.BatchNormalization object at 0x7f4473ea7d10>
# 288 : batchnormalization_91, <keras.layers.normalization.BatchNormalization object at 0x7f4473e49c50>
# 289 : convolution2d_88, <keras.layers.convolutional.Convolution2D object at 0x7f4473e036d0>
# 290 : convolution2d_88__activation__, <keras.layers.core.Activation object at 0x7f44775bc2d0>
# 291 : convolution2d_89, <keras.layers.convolutional.Convolution2D object at 0x7f4473d88bd0>
# 292 : convolution2d_89__activation__, <keras.layers.core.Activation object at 0x7f44775bc190>
# 293 : convolution2d_92, <keras.layers.convolutional.Convolution2D object at 0x7f4473d629d0>
# 294 : convolution2d_92__activation__, <keras.layers.core.Activation object at 0x7f44775bc1d0>
# 295 : convolution2d_93, <keras.layers.convolutional.Convolution2D object at 0x7f4473d087d0>
# 296 : convolution2d_93__activation__, <keras.layers.core.Activation object at 0x7f44775bc110>
# 297 : averagepooling2d_10, <keras.layers.pooling.AveragePooling2D object at 0x7f4473d2ab50>
# 298 : convolution2d_86, <keras.layers.convolutional.Convolution2D object at 0x7f4473cd0c90>
# 299 : convolution2d_86__activation__, <keras.layers.core.Activation object at 0x7f44775bc310>
# 300 : batchnormalization_88, <keras.layers.normalization.BatchNormalization object at 0x7f4473ce28d0>
# 301 : batchnormalization_89, <keras.layers.normalization.BatchNormalization object at 0x7f4473cf5e90>
# 302 : batchnormalization_92, <keras.layers.normalization.BatchNormalization object at 0x7f4473c99a50>
# 303 : batchnormalization_93, <keras.layers.normalization.BatchNormalization object at 0x7f4473c1b850>
# 304 : convolution2d_94, <keras.layers.convolutional.Convolution2D object at 0x7f4473b8bb10>
# 305 : convolution2d_94__activation__, <keras.layers.core.Activation object at 0x7f44775bc090>
# 306 : batchnormalization_86, <keras.layers.normalization.BatchNormalization object at 0x7f4473b0f390>
# 307 : mixed9_1, <keras.engine.topology.Merge object at 0x7f4473a80e10>
# 308 : merge_2, <keras.engine.topology.Merge object at 0x7f4473aa39d0>
# 309 : batchnormalization_94, <keras.layers.normalization.BatchNormalization object at 0x7f4473aba690>
# 310 : mixed10, <keras.engine.topology.Merge object at 0x7f4473a6ac10>
# 311 : averagepooling2d_11, <keras.layers.pooling.AveragePooling2D object at 0x7f4473a25950>
# 312 : flatten_1, <keras.layers.core.Flatten object at 0x7f44739fec10>
# 313 : dense_1, <keras.layers.core.Dense object at 0x7f4473995810>
# 314 : dense_1__activation__, <keras.layers.core.Activation object at 0x7f44775bc210>

# %% [markdown]
# ## Add metadata

# %%
coreml_model.author = 'Udacity'
coreml_model.license = 'MIT'
coreml_model.short_description = 'Classifies food from an image as one of 101 classes'
coreml_model.input_description['image'] = 'Food image'
coreml_model.output_description['confidence'] = 'Confidence of the food classification'
coreml_model.output_description['classLabel'] = 'Food classification label'

# %% [markdown]
# ## Inspect Core ML model

# %%
coreml_model
# Out:
# input {
#   name: "image"
#   type {
#     imageType {
#       width: 299
#       height: 299
#       colorSpace: RGB
#     }
#   }
# }
# output {
#   name: "confidence"
#   type {
#     dictionaryType {
#       stringKeyType {
#       }
#     }
#   }
# }
# output {
#   name: "classLabel"
#   type {
#     stringType {
#     }
#   }
# }
# predictedFeatureName: "classLabel"
# predictedProbabilitiesName: "confidence"

# %% [markdown]
# ## Save to .mlmodel

# %%
coreml_model.save('Food101Net.mlmodel')
